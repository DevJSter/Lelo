# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a sample dataset
data = {'value': [15, 28, 32, 40, 52, 58, 60, 70, 75, 80, 90, 100]}
df = pd.DataFrame(data)

# Define custom bin edges for 3 bins
bin_edges = [0, 40, 70, 100]  # Adjust bin edges as needed

# Discretize the data using pandas.cut()
df['bin'] = pd.cut(df['value'], bins=bin_edges, labels=['Low', 'Medium', 'High'])

# Print the bins
print("Bins:")
print(pd.cut(df['value'], bins=bin_edges))

# Plot histogram
plt.figure(figsize=(8, 6))
plt.hist(df['value'], bins=bin_edges, color='blue', alpha=0.7, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Value')
plt.xticks(bin_edges)
plt.show()

# Plot scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(df['value'], df['bin'], color='green', alpha=0.7)
plt.xlabel('Value')
plt.ylabel('Bin')
plt.title('Scatter Plot of Value vs. Bin')
plt.yticks(df['bin'].unique())
plt.show()
# Out:
# Bins:
# 0       (0, 40]
# 1       (0, 40]
# 2       (0, 40]
# 3       (0, 40]
# 4      (40, 70]
# 5      (40, 70]
# 6      (40, 70]
# 7      (40, 70]
# 8     (70, 100]
# 9     (70, 100]
# 10    (70, 100]
# 11    (70, 100]
# Name: value, dtype: category
# Categories (3, interval[int64, right]): [(0, 40] < (40, 70] < (70, 100]]
